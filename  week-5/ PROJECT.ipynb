# %%
 import tkinter as tk
from tkinter import messagebox

# Employee data 
employees = {
    "Oluwatamilore": "Logistics",
    "Ayomide": "Accounting",
    "Oshim": "Delivery",
    "Chukwunonye": "Accounting",
    "Chiemeziem": "Logistics",
    "Oluwatimehin": "Accounting",
    "Osose": "Logistics",
    "Daniel": "Delivery",
    "Onyekachi": "Delivery",
    "Shalom": "Delivery",
    "Nedi": "Logistics",
    "Stephanie": "Accounting",
    "Jason": "Administration",
    "Edward": "Delivery",
    "Otu": "Administration",
    "Onyinechi": "Administration",
    "Makuochukwu": "Logistics",
    "Moyosore": "Logistics",
    "Ayonete": "Accounting",
    "Eche": "Accounting",
    "Micheal": "Delivery",
    "Oluwadamilola": "Delivery",
    "Chijindu": "Logistics",
    "Joseph": "Logistics",
    "Daisy": "Accounting",
    "Samuel": "Accounting",
    "Betha":  "Accounting",
    "Boluwatife": "Delivery",
    "Mary": "Delivery",
    "Raphael": "Administration",
    "Victor": "Administration",
    "Derek": "Logistics",
    "Akorede": "Accounting",
    "Rasheed": "Accounting",
    "Daniel": "Accounting",
    "Mary-Cynthia": "Logistics",
    "Owoede": "Logistics",
    "Oluwafikunmi": "Delivery",
    "Uchenna": "Delivery",
    "Ejike": "Administration",
}

def welcome_message(name, department):
    # Create a welcome message for the employee
    welcome_message = f"Welcome {name}!\nYou are part of the {department} department."

    # Get other employees in the same department
    department_employees = [emp for emp, dept in employees.items() if dept == department and emp != name]

    # Create a message with other department members
    if department_employees:
        members_message = f"\nOther members of the {department} department:\n"
        members_message += "\n".join(department_employees)
    else:
        members_message = f"\nYou are the only member of the {department} department."

    # Show the welcome message with department members
    messagebox.showinfo("Welcome", welcome_message + members_message)

def submit():
    name = name_entry.get().lower()
    department = department_entry.get().lower()

    # Check if Name and Department match the conditionss
    if (name == "Oluwatamilore" and department == "Logistics") or \
       (name == "Ayomide" and department == "Accounting") or \
       (name == "Oshim" and department == "Delivery") or \
       (name == "Chukwunonye" and department == "Accounting") or \
       (name == "Chiemeziem" and department == "Logistics") or \
       (name == "Oluwatimehin" and department == "Accounting") or \
       (name == "Osose" and department == "Logistics") or \
       (name == "Daniel" and department == "Delivery") or \
       (name == "Onyekachi" and department == "Delivery") or \
       (name == "Shalom" and department == "Delivery") or \
       (name == "Nedi" and department == "Logistics") or \
       (name == "Stephanie" and department == "Accounting") or \
       (name == "Jason" and department == "Administration") or \
       (name == "Edward" and department == "Delivery") or \
       (name == "Otu" and department == "Administration") or \
       (name == "Onyinechi" and department == "Administration") or \
       (name == "Makuochukwu" and department == "Logistics") or \
       (name == "Moyosore" and department == "Logistics") or \
       (name == "Ayonete" and department == "Accounting") or \
       (name == "Eche" and department == "Accounting") or \
       (name == "Micheal" and department == "Delivery") or \
       (name == "Oluwadamilola" and department == "Delivery") or \
       (name == "Chijindu" and department == "Logistics") or \
       (name == "Joseph" and department == "Logistics") or \
       (name == "Daisy" and department == "Accounting") or \
       (name == "Samuel" and department == "Accounting") or \
       (name == "Betha" and department == "Accounting") or \
       (name == "Boluwatife" and department == "Delivery") or \
       (name == "Mary" and department == "Delivery") or \
       (name == "Raphael" and department == "Administration") or \
       (name == "Victor" and department == "Administration") or \
       (name == "Derek" and department == "Logistics") or \
       (name == "Akorede" and department == "Accounting") or \
       (name == "Rasheed" and department == "Accounting") or \
       (name == "Daniel" and department == "Accounting") or \
       (name == "Mary-Cynthia" and department == "Logistics") or \
       (name == "Owoede" and department == "Logistics") or \
       (name == "Oluwafikunmi" and department == "Delivery") or \
       (name == "Uchenna" and department == "Delivery") or \
       (name == "Ejike" and department == "Administration"):
        welcome_message(name, department)
    else:
        messagebox.showerror("Failed", "Employee does not exist")

# Create main window
root = tk.Tk()
root.title("Member validation form")
root.geometry("500x200")

# Create username label and entry
name_label = tk.Label(root, text="Name:")
name_label.pack()
name_entry = tk.Entry(root)
name_entry.pack()

# Create department label and entry
department_label = tk.Label(root, text="Department:")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

# Create submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
